# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithila-Mehedi/AmazoWebScraping/blob/main/Audio_detection_for_aviation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa as lr
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import IPython.display as ipd
import keras
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pickle as pk
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
dataset = '/content/drive/MyDrive/Audio detection for aviation/Whistler Radio Rec'

# %%
files = pd.DataFrame(os.listdir(dataset),columns=['files'])

# %%
recording = files[1:]
recording
# Out:
#             files
# 1     9_6_Millard
# 2     9_5_Millard
# 3    8_28_MILLARD
# 4    9_30_Millard
# 5    9_18_Millard
# 6    9_27_Millard
# 7     9_9_Millard
# 8    8_29_Millard
# 9     9_2_Millard
# 10   9_26_Millard
# 11   6_08_Millard
# 12  12_12_Millard
# 13   6_26_Millard
# 14   6_20_Millard
# 15   8_26_MILLARD
# 16   6_24_Millard
# 17   6_29_Millard
# 18   8_25_MILLARD
# 19   5_31_Millard
# 20   8_27_MILLARD
# 21  10_17_Millard
# 22  12_11_Millard
# 23   10_9_Millard
# 24  10_19_Millard
# 25  11_28_Millard
# 26  10_20_Millard
# 27   10_1_Millard
# 28   11_3_Millard
# 29  11_30_Millard
# 30   11_7_Millard

# %%
def count(path):
    size = []
    directories = os.listdir(path)[1:]  # Skip the first directory (index 0)
    for file in directories:
        size.append(len(os.listdir(os.path.join(path, file))))
    return pd.DataFrame(size, columns=['Number Of Sample'], index=directories)

tr = count(dataset)
tr
# Out:
#                Number Of Sample
# 9_6_Millard                  18
# 9_5_Millard                  48
# 8_28_MILLARD                101
# 9_30_Millard                 32
# 9_18_Millard                  6
# 9_27_Millard                163
# 9_9_Millard                   5
# 8_29_Millard                 56
# 9_2_Millard                   4
# 9_26_Millard                137
# 6_08_Millard                141
# 12_12_Millard               150
# 6_26_Millard                 22
# 6_20_Millard                 34
# 8_26_MILLARD                134
# 6_24_Millard                 42
# 6_29_Millard                122
# 8_25_MILLARD                 37
# 5_31_Millard                 68
# 8_27_MILLARD                  7
# 10_17_Millard                83
# 12_11_Millard               365
# 10_9_Millard                116
# 10_19_Millard               138
# 11_28_Millard                59
# 10_20_Millard                41
# 10_1_Millard                 11
# 11_3_Millard                146
# ...

# %%
# !pip install pydub

# %%
from pydub import AudioSegment
from pydub.utils import make_chunks

# %%
# !pip install librosa

# %%
# !pip install SpeechRecognition

# %%
# !pip install ffmpeg

# %%
import speech_recognition as sr
from pydub import AudioSegment

# Initialize recognizer
recognizer = sr.Recognizer()

def speech_to_text(audio_path):
  # Convert audio file to a format recognized by SpeechRecognition (if needed)
  # If your file is already in .wav format, you can skip this step
  audio = AudioSegment.from_file(audio_path)
  audio.export("converted_audio.wav", format="wav")

  # Load the audio file
  with sr.AudioFile("converted_audio.wav") as source:
      audio_data = recognizer.record(source)  # Read the entire audio file

  # Recognize speech using Google Web Speech API
  try:
      text = recognizer.recognize_google(audio_data)
      return text
  except:
    return 'Error'

# %%
# prompt: grab the first folder and list the audio clip

all_folders = os.listdir(dataset)[1:]
print('folders: ', all_folders)

folder_path = os.path.join(dataset, '6_20_Millard')
audio_clips = os.listdir(folder_path)
print(audio_clips)
# Out:
# folders:  ['9_6_Millard', '9_5_Millard', '8_28_MILLARD', '9_30_Millard', '9_18_Millard', '9_27_Millard', '9_9_Millard', '8_29_Millard', '9_2_Millard', '9_26_Millard', '6_08_Millard', '12_12_Millard', '6_26_Millard', '6_20_Millard', '8_26_MILLARD', '6_24_Millard', '6_29_Millard', '8_25_MILLARD', '5_31_Millard', '8_27_MILLARD', '10_17_Millard', '12_11_Millard', '10_9_Millard', '10_19_Millard', '11_28_Millard', '10_20_Millard', '10_1_Millard', '11_3_Millard', '11_30_Millard', '11_7_Millard']
# ['017.AU', '018.AU', '037.AU', '015.AU', '036.AU', '010.AU', '029.AU', '009.AU', '011.AU', '032.AU', '030.AU', '013.AU', '014.AU', '026.AU', '021.AU', '034.AU', '023.AU', '016.AU', '028.AU', '038.AU', '024.AU', '031.AU', '027.AU', '019.AU', '008.AU', '035.AU', '022.AU', '020.AU', '012.AU', '025.AU', '033.AU', '039.AU', '6_20_Millard.xlsx', '040.AU']

# %%
def sort_strings(str_list):
  print('str list: ', str_list)
  return sorted(str_list, key=lambda x: int(x.split('.')[0]))

filtered_audio_clips = [x for x in audio_clips if not x.endswith('.xlsx')]
sorted_audio_clips = sort_strings(filtered_audio_clips)

for clip in sorted_audio_clips:
  audio_path = os.path.join(folder_path, clip)
  text = speech_to_text(audio_path)
  print('Transcripted text for: ', clip, ': ', text)
# Out:
# str list:  ['017.AU', '018.AU', '037.AU', '015.AU', '036.AU', '010.AU', '029.AU', '009.AU', '011.AU', '032.AU', '030.AU', '013.AU', '014.AU', '026.AU', '021.AU', '034.AU', '023.AU', '016.AU', '028.AU', '038.AU', '024.AU', '031.AU', '027.AU', '019.AU', '008.AU', '035.AU', '022.AU', '020.AU', '012.AU', '025.AU', '033.AU', '039.AU', '040.AU']
# Transcripted text for:  008.AU :  Error
# Transcripted text for:  009.AU :  Error
# Transcripted text for:  010.AU :  what's the temperature in 2144 West
# Transcripted text for:  011.AU :  Error
# Transcripted text for:  012.AU :  Error
# Transcripted text for:  013.AU :  two
# Transcripted text for:  014.AU :  is there a traffic ticket number 11042 x-ray left down with want to
# Transcripted text for:  015.AU :  traffic ticket number 10426
# Transcripted text for:  016.AU :  Error
# Transcripted text for:  017.AU :  Error
# Transcripted text for:  018.AU :  is there a traffic ticket number 11042 activate
# ...
